# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
new_lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
new_lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
new_lat_lngs = zip(new_lats, new_lngs)
new_lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(new_lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

cities
# Out:
# ['hilo',
#  'pitimbu',
#  'lagoa',
#  'busselton',
#  'nikolskoye',
#  'cabedelo',
#  'mataura',
#  'vaini',
#  'hambantota',
#  'upernavik',
#  'illoqqortoormiut',
#  'butaritari',
#  'chingirlau',
#  'cape town',
#  'hobart',
#  'faanui',
#  'qaanaaq',
#  'saint-philippe',
#  'port alfred',
#  'coihaique',
#  'cherskiy',
#  'hithadhoo',
#  'marsa matruh',
#  'nha trang',
#  'kaitangata',
#  'albany',
#  'yellowknife',
#  'port elizabeth',
#  'husavik',
#  'kavieng',
#  'tuktoyaktuk',
#  'isangel',
#  'livramento',
#  'alzamay',
#  'ushuaia',
#  'kruisfontein',
#  'cap-aux-meules',
#  'mount darwin',
#  'mar del plata',
#  'cap malheureux',
#  'shingu',
#  'avarua',
#  'salalah',
#  'kapaa',
#  'mitsamiouli',
#  'chuy',
#  'punta arenas',
#  'tiksi',
#  'okhotsk',
#  'tuatapere',
#  'buin',
#  'maua',
#  'wolmaranstad',
#  'lebu',
#  'nizhneyansk',
#  'khatanga',
#  'adre',
#  'airai',
#  'kostino',
#  'tawkar',
#  'jamestown',
#  'kuytun',
#  'bredasdorp',
#  'bilibino',
#  'rio grande',
#  'dakar',
#  'pacific grove',
#  'plouzane',
#  'saleaula',
#  'constitucion',
#  'marawi',
#  'bluff',
#  'guerrero negro',
#  'grindavik',
#  'provideniya',
#  'puerto ayora',
#  'hofn',
#  'souillac',
#  'longyearbyen',
#  'yantzaza',
#  'severnyy',
#  'saint george',
#  'east london',
#  'rikitea',
#  'atuona',
#  'bindura',
#  'sao felix do xingu',
#  'port moresby',
#  'barcelona',
#  'beringovskiy',
#  'torbay',
#  'lazaro cardenas',
#  'mehamn',
#  'alto araguaia',
#  'bolungarvik',
#  'poum',
#  'kamphaeng phet',
#  'thompson',
#  'haverfordwest',
#  'blagoyevo',
#  'suluq',
#  'uruzgan',
#  'zhigansk',
#  'aras',
#  'morros',
#  'narsaq',
#  'tasiilaq',
#  'tessalit',
#  'vestmannaeyjar',
#  'mildura',
#  'dumas',
#  'ayan',
#  'la crosse',
#  'santa isabel do rio negro',
#  'barrow',
#  'yerbogachen',
#  'udachnyy',
#  'camacha',
#  'bubaque',
#  'waingapu',
#  'taolanaro',
#  'asau',
#  'pevek',
#  'samusu',
#  'kamenskoye',
#  'port blair',
#  'burnie',
#  'castro',
#  'traverse city',
#  'kahului',
#  'bethel',
#  'aquiraz',
#  'burica',
#  'ostrovnoy',
#  'amderma',
#  'sanandaj',
#  'umm lajj',
#  'vaitupu',
#  'ancona',
#  'rocha',
#  'luena',
#  'bocana de paiwas',
#  'dikson',
#  'severo-kurilsk',
#  'barentsburg',
#  'krasnoselkup',
#  'saskylakh',
#  'inta',
#  'roald',
#  'abu dhabi',
#  'kenai',
#  'tracy',
#  'synya',
#  'ferkessedougou',
#  'haines junction',
#  'bonavista',
#  'catuday',
#  'rupert',
#  'arman',
#  'kulhudhuffushi',
#  'tura',
#  'sungaipenuh',
#  'sitka',
#  'northam',
#  'terney',
#  'huarmey',
#  'grand river south east',
#  'georgetown',
#  'hermanus',
#  'goderich',
#  'pangnirtung',
#  'gizo',
#  'fortuna',
#  'anchorage',
#  'barawe',
#  'mantua',
#  'coihueco',
#  'japura',
#  'santa luzia',
#  'sao joao da barra',
#  'satitoa',
#  'garowe',
#  'dwarka',
#  'ilulissat',
#  'barbar',
#  'nioro',
#  'surin',
#  'belushya guba',
#  'milingimbi',
#  'balabac',
#  'esperance',
#  'mount isa',
#  'jalu',
#  'churumuco',
#  'taoudenni',
#  'west plains',
#  'thunder bay',
#  'new norfolk',
#  'pingxiang',
#  'asosa',
#  'talara',
#  'okahandja',
#  'middletown',
#  'lorengau',
#  'amapa',
#  'port lincoln',
#  'sobolevo',
#  'chokurdakh',
#  'altay',
#  'srednekolymsk',
#  'sao geraldo do araguaia',
#  'smoky lake',
#  'itanhem',
#  'kamaishi',
#  'artyom',
#  'westport',
#  'port hardy',
#  'bocaiuva',
#  'kumbo',
#  'gilleleje',
#  'fort nelson',
#  'kamyshla',
#  'mankera',
#  'pleszew',
#  'padang',
#  'tsihombe',
#  'bambous virieux',
#  'arraial do cabo',
#  'hunza',
#  'konstantinovskiy',
#  'ketchikan',
#  'saiha',
#  'miri',
#  'roros',
#  'rendsburg',
#  'teguise',
#  'yulara',
#  'coquimbo',
#  'sfantu gheorghe',
#  'flinders',
#  'auki',
#  'staroaleyskoye',
#  'kamenka',
#  'lavrentiya',
#  'adrar',
#  'mackenzie',
#  'mahadday weyne',
#  'chabahar',
#  'staryy nadym',
#  'marzuq',
#  'palmas',
#  'laguna',
#  'pisco',
#  'mys shmidta',
#  'lichinga',
#  'altamont',
#  'luderitz',
#  'victoria',
#  'baykit',
#  'barcelos',
#  'skjervoy',
#  'longlac',
#  'tsaratanana',
#  'kavaratti',
#  'omboue',
#  'bulawayo',
#  'kristiinankaupunki',
#  'necochea',
#  'aldan',
#  'cueto',
#  'agropoli',
#  'iqaluit',
#  'queimadas',
#  'vreed en hoop',
#  'wettingen',
#  'ponta do sol',
#  'ust-ilimsk',
#  'vila',
#  'makakilo city',
#  'celestun',
#  'nizhniy kuranakh',
#  'xacmaz',
#  'ingham',
#  'nakamura',
#  'hobbs',
#  'dublin',
#  'sola',
#  'gornopravdinsk',
#  'yumen',
#  'sibolga',
#  'nanortalik',
#  'kodiak',
#  'cockburn town',
#  'abu samrah',
#  'seoul',
#  'moa',
#  'aksarka',
#  'cidreira',
#  'marathon',
#  'coromandel',
#  'san quintin',
#  'lagos',
#  'darnah',
#  'college',
#  'mathathane',
#  'ulaangom',
#  'kupang',
#  'bengkulu',
#  'moose factory',
#  'ust-omchug',
#  'puerto carreno',
#  'cayenne',
#  'axim',
#  'dingle',
#  'kysyl-syr',
#  'roma',
#  'ahipara',
#  'deori khas',
#  'manggar',
#  'san carlos de bariloche',
#  'carnarvon',
#  'gavrilovka vtoraya',
#  'livingstonia',
#  'sioux lookout',
#  'codrington',
#  'luwuk',
#  'mount gambier',
#  'edd',
#  'berlevag',
#  'springdale',
#  'nouadhibou',
#  'te anau',
#  'avera',
#  'nguiu',
#  'sao jose da coroa grande',
#  'komatipoort',
#  'nome',
#  'sumbe',
#  'bosaso',
#  'rockhampton',
#  'shangqiu',
#  'chicama',
#  'santa isabel',
#  'navahrudak',
#  'ixtapa',
#  'severnyy-kospashskiy',
#  'verkhnyaya inta',
#  'lasa',
#  'garden city',
#  'san cristobal',
#  'alexandria',
#  'buchanan',
#  'onega',
#  'peleduy',
#  'gazojak',
#  'nantucket',
#  'shenzhen',
#  'aguas vermelhas',
#  'tingrela',
#  'denpasar',
#  'crevenicu',
#  'vila franca do campo',
#  'hamilton',
#  'campbeltown',
#  'kidal',
#  'sao goncalo do amarante',
#  'clyde river',
#  'muswellbrook',
#  'ziniare',
#  'chadiza',
#  'attawapiskat',
#  'warqla',
#  'salekhard',
#  'bud',
#  'ranong',
#  'udalguri',
#  'puerto suarez',
#  'belyy yar',
#  'kathu',
#  'pak phanang',
#  'tianpeng',
#  'hornepayne',
#  'matay',
#  'wahiawa',
#  'tekeli',
#  'tual',
#  'finnsnes',
#  'eskil',
#  'cartagena',
#  'lander',
#  'xining',
#  'brae',
#  'katsuura',
#  'dolbeau',
#  'matara',
#  'oum hadjer',
#  'karratha',
#  'katiola',
#  'kopavogur',
#  'keflavik',
#  'mulege',
#  'chapais',
#  'rawson',
#  'maragogi',
#  'eyl',
#  'sao filipe',
#  'zonguldak',
#  'kalmunai',
#  'kingaroy',
#  'ancud',
#  'sentyabrskiy',
#  'carnot',
#  'aksay',
#  'prince rupert',
#  'tautira',
#  'yoichi',
#  'komsomolskiy',
#  'klaksvik',
#  'sabang',
#  'methoni',
#  'coos bay',
#  'leningradskiy',
#  'port augusta',
#  'bargal',
#  'boa vista',
#  'surt',
#  'tasbuget',
#  'elko',
#  'naron',
#  'zhangye',
#  'pihuamo',
#  'el alto',
#  'misratah',
#  'kasongo-lunda',
#  'saint-georges',
#  'fiumicino',
#  'mahebourg',
#  'san jose',
#  'vredendal',
#  'hualmay',
#  'moindou',
#  'la ronge',
#  'taywarah',
#  'manzil salim',
#  'kudahuvadhoo',
#  'dongsheng',
#  'bataraza',
#  'prado',
#  'loviisa',
#  'calvia',
#  'nalut',
#  'mabaruma',
#  'corinth',
#  'khomeyn',
#  'akyab',
#  'takoradi',
#  'apatou',
#  'portobelo',
#  'sergeyevka',
#  'naze',
#  'junagarh',
#  'bati',
#  'ziyang',
#  'lompoc',
#  'carcassonne',
#  'valverde del camino',
#  'vikhorevka',
#  'nagato',
#  'port arthur',
#  'portland',
#  'ogaminana',
#  'dedovichi',
#  'cheuskiny',
#  'aripuana',
#  'surazh',
#  'clarence town',
#  'brattvag',
#  'ahuimanu',
#  'khorixas',
#  'svetlaya',
#  'upata',
#  'tumannyy',
#  'asuncion nochixtlan',
#  'itoman',
#  'palauig',
#  'bay city',
#  'cabo san lucas',
#  'mayumba',
#  'zvishavane',
#  'kirkwall',
#  'waitati',
#  'preobrazheniye',
#  'deputatskiy',
#  'nelson bay',
#  'vanimo',
#  'atasu',
#  'bull savanna',
#  'vytegra',
#  'khingansk',
#  'bedesa',
#  'hoi an',
#  'linkoping',
#  'mayor pablo lagerenza',
#  'caravelas',
#  'abnub',
#  'lagoa da prata',
#  'harwich',
#  'pinillos',
#  'monte patria',
#  'dawei',
#  'nyurba',
#  'itarema',
#  'tyup',
#  'cullman',
#  'paamiut',
#  'palmer',
#  'sherpur',
#  'juneau',
#  'sayyan',
#  'kloulklubed',
#  'kurumkan',
#  'hrebinka',
#  'vao',
#  'mindelheim',
#  'cervo',
#  'lata',
#  'mazatlan',
#  'port-gentil',
#  'kirkland lake',
#  'bathsheba',
#  'dalby',
#  'campbell river',
#  'lidkoping',
#  'broome',
#  'birin',
#  'huanren',
#  'maroantsetra',
#  'ararat',
#  'cehegin',
#  'egvekinot',
#  'haapu',
#  'grand centre',
#  'ishigaki',
#  'castro alves',
#  'saint anthony',
#  'umzimvubu',
#  'lima',
#  'grand-santi',
#  'ginir',
#  'olafsvik',
#  'tigil',
#  'berbera',
#  'kununurra',
#  'abilene',
#  'soyo',
#  'sao raimundo nonato',
#  'bur gabo',
#  'tabiauea',
#  'loukhi',
#  'irbit',
#  'sur',
#  'biggar',
#  'pontian kecil',
#  'bama',
#  'gurgan',
#  'porto novo',
#  'acapulco',
#  'morondava',
#  'baturaja',
#  'abidjan',
#  'georgiyevka',
#  'raudeberg',
#  'saint-joseph',
#  'mingaora',
#  'geraldton',
#  'codigoro',
#  'sisimiut',
#  'vostok',
#  'santiago del estero',
#  'nagorsk',
#  'bongandanga',
#  'taltal',
#  'horsham',
#  'alofi',
#  'comodoro rivadavia',
#  'arlit',
#  'ruatoria',
#  'kaeo',
#  'trebinje',
#  'lakselv',
#  'ardistan',
#  'motygino',
#  'wakema',
#  'chagda',
#  'jertih',
#  'suntar',
#  'afmadu',
#  'fairbanks',
#  'manadhoo',
#  'vila do maio',
#  'henties bay',
#  'atambua',
#  'marcona',
#  'valer',
#  'ystad',
#  'nara',
#  'livadiya',
#  'darhan',
#  'novobirilyussy',
#  'chara',
#  'alice springs',
#  'tectitan',
#  'tongliao',
#  'palana',
#  'benjamin constant',
#  'baringo',
#  'muros',
#  'karakulino',
#  'marinette',
#  'emerald',
#  'yako',
#  'maldonado',
#  'walvis bay',
#  'murillo',
#  'yingshang',
#  'bantry',
#  'gold coast',
#  'zemetchino',
#  'dalnerechensk',
#  'cabra',
#  'kiunga',
#  'tahoua',
#  'sakaraha',
#  'itaituba',
#  'batagay-alyta',
#  'erenhot',
#  'atar',
#  'port macquarie',
#  'payo',
#  'valdivia',
#  'aporawan',
#  'pietarsaari',
#  'carauari',
#  'kiel',
#  'ribeira grande',
#  'katangli',
#  'mujiayingzi',
#  'poshekhonye',
#  'gamba',
#  'aklavik',
#  'dzaoudzi',
#  'hasaki',
#  'elmina',
#  'labuhan',
#  'roquebrune-cap-martin',
#  'palabuhanratu',
#  'bacabal',
#  'ngukurr',
#  'dapaong',
#  'gornoye loo',
#  'saldanha',
#  'xianyang',
#  'fredericksburg',
#  'vila velha',
#  'koboldo',
#  'san luis',
#  'milledgeville',
#  'merauke',
#  'victor harbor',
#  'shadegan',
#  'bulgan',
#  'krasnoarmeysk',
#  'rassvet',
#  'kolokani',
#  'narsipatnam',
#  'gat',
#  'cassilandia',
#  'kvareli',
#  'fare',
#  'silifke',
#  'reconquista',
#  'pochutla',
#  'bilma',
#  'dutse',
#  'hit',
#  'larap',
#  'shimanovsk',
#  'skagen',
#  'salinopolis',
#  'nivala',
#  'cay',
#  'russell',
#  'camana',
#  'beisfjord',
#  'dhidhdhoo',
#  'mondlo',
#  'waddan',
#  'aberlady',
#  'sedelnikovo',
#  'uttaradit',
#  'tabarqah',
#  'liniere',
#  'miraflores',
#  'jibuti',
#  'sambava',
#  'san patricio',
#  'mayo',
#  'consuelo',
#  'touros',
#  'port hedland',
#  'wasilla',
#  'ballyshannon',
#  'hibbing',
#  'road town',
#  'krasnoyarsk-66',
#  'ugoofaaru',
#  'tillabery',
#  'korla',
#  'viedma',
#  'rawannawi',
#  'trujillo',
#  'alyangula',
#  'mocuba',
#  'beidao',
#  'mrirt',
#  'mbini',
#  'makat',
#  'cuamba',
#  'nizhnevartovsk',
#  'termini imerese',
#  'haibowan',
#  'sofiysk',
#  'zakamensk',
#  'el balyana',
#  'aranos',
#  'fuyu',
#  'batagay',
#  'benguela',
#  'namatanai',
#  'filingue',
#  'ascension',
#  'shubarshi',
#  'inuvik',
#  'san francisco',
#  'wyszkow',
#  'jacareacanga',
#  'nicoya',
#  'ziarat',
#  'keningau',
#  'ushtobe',
#  'mackay',
#  'okha',
#  'tingo maria',
#  'yuzhno-yeniseyskiy',
#  'trelew',
#  'senador jose porfirio',
#  'angoram',
#  'araouane',
#  'aflu',
#  'jutiapa',
#  'sangolqui',
#  'lishui']

# %%
# Dependencies
import requests
import time

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()

        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_desc})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hilo
# Processing Record 2 of Set 1 | pitimbu
# Processing Record 3 of Set 1 | lagoa
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | nikolskoye
# Processing Record 6 of Set 1 | cabedelo
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | hambantota
# Processing Record 10 of Set 1 | upernavik
# Processing Record 11 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 1 | butaritari
# Processing Record 13 of Set 1 | chingirlau
# Processing Record 14 of Set 1 | cape town
# Processing Record 15 of Set 1 | hobart
# Processing Record 16 of Set 1 | faanui
# Processing Record 17 of Set 1 | qaanaaq
# Processing Record 18 of Set 1 | saint-philippe
# Processing Record 19 of Set 1 | port alfred
# Processing Record 20 of Set 1 | coihaique
# Processing Record 21 of Set 1 | cherskiy
# Processing Record 22 of Set 1 | hithadhoo
# Processing Record 23 of Set 1 | marsa matruh
# Processing Record 24 of Set 1 | nha trang
# Processing Record 25 of Set 1 | kaitangata
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | yellowknife
# Processing Record 28 of Set 1 | port elizabeth
# Processing Record 29 of Set 1 | husavik
# Processing Record 30 of Set 1 | kavieng
# Processing Record 31 of Set 1 | tuktoyaktuk
# Processing Record 32 of Set 1 | isangel
# Processing Record 33 of Set 1 | livramento
# Processing Record 34 of Set 1 | alzamay
# Processing Record 35 of Set 1 | ushuaia
# Processing Record 36 of Set 1 | kruisfontein
# Processing Record 37 of Set 1 | cap-aux-meules
# Processing Record 38 of Set 1 | mount darwin
# Processing Record 39 of Set 1 | mar del plata
# Processing Record 40 of Set 1 | cap malheureux
# Processing Record 41 of Set 1 | shingu
# Processing Record 42 of Set 1 | avarua
# Processing Record 43 of Set 1 | salalah
# Processing Record 44 of Set 1 | kapaa
# Processing Record 45 of Set 1 | mitsamiouli
# Processing Record 46 of Set 1 | chuy
# Processing Record 47 of Set 1 | punta arenas
# Processing Record 48 of Set 1 | tiksi
# Processing Record 49 of Set 1 | okhotsk
# Processing Record 50 of Set 1 | tuatapere
# Processing Record 1 of Set 2 | buin
# Processing Record 2 of Set 2 | maua
# Processing Record 3 of Set 2 | wolmaranstad
# City not found. Skipping...
# Processing Record 4 of Set 2 | lebu
# Processing Record 5 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 2 | khatanga
# Processing Record 7 of Set 2 | adre
# Processing Record 8 of Set 2 | airai
# Processing Record 9 of Set 2 | kostino
# Processing Record 10 of Set 2 | tawkar
# City not found. Skipping...
# Processing Record 11 of Set 2 | jamestown
# Processing Record 12 of Set 2 | kuytun
# Processing Record 13 of Set 2 | bredasdorp
# Processing Record 14 of Set 2 | bilibino
# Processing Record 15 of Set 2 | rio grande
# Processing Record 16 of Set 2 | dakar
# Processing Record 17 of Set 2 | pacific grove
# Processing Record 18 of Set 2 | plouzane
# Processing Record 19 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 2 | constitucion
# Processing Record 21 of Set 2 | marawi
# Processing Record 22 of Set 2 | bluff
# Processing Record 23 of Set 2 | guerrero negro
# Processing Record 24 of Set 2 | grindavik
# Processing Record 25 of Set 2 | provideniya
# Processing Record 26 of Set 2 | puerto ayora
# Processing Record 27 of Set 2 | hofn
# Processing Record 28 of Set 2 | souillac
# Processing Record 29 of Set 2 | longyearbyen
# Processing Record 30 of Set 2 | yantzaza
# Processing Record 31 of Set 2 | severnyy
# Processing Record 32 of Set 2 | saint george
# Processing Record 33 of Set 2 | east london
# Processing Record 34 of Set 2 | rikitea
# Processing Record 35 of Set 2 | atuona
# Processing Record 36 of Set 2 | bindura
# Processing Record 37 of Set 2 | sao felix do xingu
# Processing Record 38 of Set 2 | port moresby
# Processing Record 39 of Set 2 | barcelona
# Processing Record 40 of Set 2 | beringovskiy
# Processing Record 41 of Set 2 | torbay
# Processing Record 42 of Set 2 | lazaro cardenas
# Processing Record 43 of Set 2 | mehamn
# Processing Record 44 of Set 2 | alto araguaia
# Processing Record 45 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 46 of Set 2 | poum
# Processing Record 47 of Set 2 | kamphaeng phet
# Processing Record 48 of Set 2 | thompson
# Processing Record 49 of Set 2 | haverfordwest
# Processing Record 50 of Set 2 | blagoyevo
# Processing Record 1 of Set 3 | suluq
# Processing Record 2 of Set 3 | uruzgan
# Processing Record 3 of Set 3 | zhigansk
# Processing Record 4 of Set 3 | aras
# Processing Record 5 of Set 3 | morros
# Processing Record 6 of Set 3 | narsaq
# Processing Record 7 of Set 3 | tasiilaq
# Processing Record 8 of Set 3 | tessalit
# Processing Record 9 of Set 3 | vestmannaeyjar
# Processing Record 10 of Set 3 | mildura
# Processing Record 11 of Set 3 | dumas
# Processing Record 12 of Set 3 | ayan
# Processing Record 13 of Set 3 | la crosse
# Processing Record 14 of Set 3 | santa isabel do rio negro
# Processing Record 15 of Set 3 | barrow
# Processing Record 16 of Set 3 | yerbogachen
# Processing Record 17 of Set 3 | udachnyy
# Processing Record 18 of Set 3 | camacha
# Processing Record 19 of Set 3 | bubaque
# Processing Record 20 of Set 3 | waingapu
# Processing Record 21 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 3 | asau
# Processing Record 23 of Set 3 | pevek
# Processing Record 24 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 26 of Set 3 | port blair
# Processing Record 27 of Set 3 | burnie
# Processing Record 28 of Set 3 | castro
# Processing Record 29 of Set 3 | traverse city
# Processing Record 30 of Set 3 | kahului
# Processing Record 31 of Set 3 | bethel
# Processing Record 32 of Set 3 | aquiraz
# Processing Record 33 of Set 3 | burica
# City not found. Skipping...
# Processing Record 34 of Set 3 | ostrovnoy
# Processing Record 35 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 3 | sanandaj
# Processing Record 37 of Set 3 | umm lajj
# Processing Record 38 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 3 | ancona
# Processing Record 40 of Set 3 | rocha
# Processing Record 41 of Set 3 | luena
# Processing Record 42 of Set 3 | bocana de paiwas
# Processing Record 43 of Set 3 | dikson
# Processing Record 44 of Set 3 | severo-kurilsk
# Processing Record 45 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 3 | krasnoselkup
# Processing Record 47 of Set 3 | saskylakh
# Processing Record 48 of Set 3 | inta
# Processing Record 49 of Set 3 | roald
# Processing Record 50 of Set 3 | abu dhabi
# Processing Record 1 of Set 4 | kenai
# Processing Record 2 of Set 4 | tracy
# Processing Record 3 of Set 4 | synya
# Processing Record 4 of Set 4 | ferkessedougou
# Processing Record 5 of Set 4 | haines junction
# Processing Record 6 of Set 4 | bonavista
# Processing Record 7 of Set 4 | catuday
# Processing Record 8 of Set 4 | rupert
# Processing Record 9 of Set 4 | arman
# Processing Record 10 of Set 4 | kulhudhuffushi
# Processing Record 11 of Set 4 | tura
# Processing Record 12 of Set 4 | sungaipenuh
# Processing Record 13 of Set 4 | sitka
# Processing Record 14 of Set 4 | northam
# Processing Record 15 of Set 4 | terney
# Processing Record 16 of Set 4 | huarmey
# Processing Record 17 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 4 | georgetown
# Processing Record 19 of Set 4 | hermanus
# Processing Record 20 of Set 4 | goderich
# Processing Record 21 of Set 4 | pangnirtung
# Processing Record 22 of Set 4 | gizo
# Processing Record 23 of Set 4 | fortuna
# Processing Record 24 of Set 4 | anchorage
# Processing Record 25 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 26 of Set 4 | mantua
# Processing Record 27 of Set 4 | coihueco
# Processing Record 28 of Set 4 | japura
# Processing Record 29 of Set 4 | santa luzia
# Processing Record 30 of Set 4 | sao joao da barra
# Processing Record 31 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 32 of Set 4 | garowe
# Processing Record 33 of Set 4 | dwarka
# Processing Record 34 of Set 4 | ilulissat
# Processing Record 35 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 36 of Set 4 | nioro
# Processing Record 37 of Set 4 | surin
# Processing Record 38 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 4 | milingimbi
# City not found. Skipping...
# Processing Record 40 of Set 4 | balabac
# Processing Record 41 of Set 4 | esperance
# Processing Record 42 of Set 4 | mount isa
# Processing Record 43 of Set 4 | jalu
# Processing Record 44 of Set 4 | churumuco
# City not found. Skipping...
# Processing Record 45 of Set 4 | taoudenni
# Processing Record 46 of Set 4 | west plains
# Processing Record 47 of Set 4 | thunder bay
# Processing Record 48 of Set 4 | new norfolk
# Processing Record 49 of Set 4 | pingxiang
# Processing Record 50 of Set 4 | asosa
# Processing Record 1 of Set 5 | talara
# Processing Record 2 of Set 5 | okahandja
# Processing Record 3 of Set 5 | middletown
# Processing Record 4 of Set 5 | lorengau
# Processing Record 5 of Set 5 | amapa
# Processing Record 6 of Set 5 | port lincoln
# Processing Record 7 of Set 5 | sobolevo
# Processing Record 8 of Set 5 | chokurdakh
# Processing Record 9 of Set 5 | altay
# Processing Record 10 of Set 5 | srednekolymsk
# Processing Record 11 of Set 5 | sao geraldo do araguaia
# Processing Record 12 of Set 5 | smoky lake
# Processing Record 13 of Set 5 | itanhem
# Processing Record 14 of Set 5 | kamaishi
# Processing Record 15 of Set 5 | artyom
# Processing Record 16 of Set 5 | westport
# Processing Record 17 of Set 5 | port hardy
# Processing Record 18 of Set 5 | bocaiuva
# Processing Record 19 of Set 5 | kumbo
# Processing Record 20 of Set 5 | gilleleje
# Processing Record 21 of Set 5 | fort nelson
# Processing Record 22 of Set 5 | kamyshla
# Processing Record 23 of Set 5 | mankera
# Processing Record 24 of Set 5 | pleszew
# Processing Record 25 of Set 5 | padang
# Processing Record 26 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 5 | bambous virieux
# Processing Record 28 of Set 5 | arraial do cabo
# Processing Record 29 of Set 5 | hunza
# City not found. Skipping...
# Processing Record 30 of Set 5 | konstantinovskiy
# Processing Record 31 of Set 5 | ketchikan
# Processing Record 32 of Set 5 | saiha
# Processing Record 33 of Set 5 | miri
# Processing Record 34 of Set 5 | roros
# Processing Record 35 of Set 5 | rendsburg
# Processing Record 36 of Set 5 | teguise
# Processing Record 37 of Set 5 | yulara
# Processing Record 38 of Set 5 | coquimbo
# Processing Record 39 of Set 5 | sfantu gheorghe
# Processing Record 40 of Set 5 | flinders
# Processing Record 41 of Set 5 | auki
# Processing Record 42 of Set 5 | staroaleyskoye
# Processing Record 43 of Set 5 | kamenka
# Processing Record 44 of Set 5 | lavrentiya
# Processing Record 45 of Set 5 | adrar
# Processing Record 46 of Set 5 | mackenzie
# Processing Record 47 of Set 5 | mahadday weyne
# City not found. Skipping...
# Processing Record 48 of Set 5 | chabahar
# Processing Record 49 of Set 5 | staryy nadym
# Processing Record 50 of Set 5 | marzuq
# Processing Record 1 of Set 6 | palmas
# Processing Record 2 of Set 6 | laguna
# Processing Record 3 of Set 6 | pisco
# Processing Record 4 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 6 | lichinga
# Processing Record 6 of Set 6 | altamont
# Processing Record 7 of Set 6 | luderitz
# Processing Record 8 of Set 6 | victoria
# Processing Record 9 of Set 6 | baykit
# Processing Record 10 of Set 6 | barcelos
# Processing Record 11 of Set 6 | skjervoy
# Processing Record 12 of Set 6 | longlac
# City not found. Skipping...
# Processing Record 13 of Set 6 | tsaratanana
# Processing Record 14 of Set 6 | kavaratti
# Processing Record 15 of Set 6 | omboue
# Processing Record 16 of Set 6 | bulawayo
# Processing Record 17 of Set 6 | kristiinankaupunki
# Processing Record 18 of Set 6 | necochea
# Processing Record 19 of Set 6 | aldan
# Processing Record 20 of Set 6 | cueto
# Processing Record 21 of Set 6 | agropoli
# Processing Record 22 of Set 6 | iqaluit
# Processing Record 23 of Set 6 | queimadas
# Processing Record 24 of Set 6 | vreed en hoop
# City not found. Skipping...
# Processing Record 25 of Set 6 | wettingen
# Processing Record 26 of Set 6 | ponta do sol
# Processing Record 27 of Set 6 | ust-ilimsk
# Processing Record 28 of Set 6 | vila
# Processing Record 29 of Set 6 | makakilo city
# Processing Record 30 of Set 6 | celestun
# Processing Record 31 of Set 6 | nizhniy kuranakh
# Processing Record 32 of Set 6 | xacmaz
# Processing Record 33 of Set 6 | ingham
# Processing Record 34 of Set 6 | nakamura
# Processing Record 35 of Set 6 | hobbs
# Processing Record 36 of Set 6 | dublin
# Processing Record 37 of Set 6 | sola
# Processing Record 38 of Set 6 | gornopravdinsk
# Processing Record 39 of Set 6 | yumen
# Processing Record 40 of Set 6 | sibolga
# Processing Record 41 of Set 6 | nanortalik
# Processing Record 42 of Set 6 | kodiak
# Processing Record 43 of Set 6 | cockburn town
# Processing Record 44 of Set 6 | abu samrah
# Processing Record 45 of Set 6 | seoul
# Processing Record 46 of Set 6 | moa
# Processing Record 47 of Set 6 | aksarka
# Processing Record 48 of Set 6 | cidreira
# Processing Record 49 of Set 6 | marathon
# Processing Record 50 of Set 6 | coromandel
# Processing Record 1 of Set 7 | san quintin
# Processing Record 2 of Set 7 | lagos
# Processing Record 3 of Set 7 | darnah
# Processing Record 4 of Set 7 | college
# Processing Record 5 of Set 7 | mathathane
# Processing Record 6 of Set 7 | ulaangom
# Processing Record 7 of Set 7 | kupang
# Processing Record 8 of Set 7 | bengkulu
# Processing Record 9 of Set 7 | moose factory
# Processing Record 10 of Set 7 | ust-omchug
# Processing Record 11 of Set 7 | puerto carreno
# Processing Record 12 of Set 7 | cayenne
# Processing Record 13 of Set 7 | axim
# Processing Record 14 of Set 7 | dingle
# Processing Record 15 of Set 7 | kysyl-syr
# Processing Record 16 of Set 7 | roma
# Processing Record 17 of Set 7 | ahipara
# Processing Record 18 of Set 7 | deori khas
# Processing Record 19 of Set 7 | manggar
# Processing Record 20 of Set 7 | san carlos de bariloche
# Processing Record 21 of Set 7 | carnarvon
# Processing Record 22 of Set 7 | gavrilovka vtoraya
# Processing Record 23 of Set 7 | livingstonia
# Processing Record 24 of Set 7 | sioux lookout
# Processing Record 25 of Set 7 | codrington
# Processing Record 26 of Set 7 | luwuk
# Processing Record 27 of Set 7 | mount gambier
# Processing Record 28 of Set 7 | edd
# Processing Record 29 of Set 7 | berlevag
# Processing Record 30 of Set 7 | springdale
# Processing Record 31 of Set 7 | nouadhibou
# Processing Record 32 of Set 7 | te anau
# Processing Record 33 of Set 7 | avera
# Processing Record 34 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 35 of Set 7 | sao jose da coroa grande
# Processing Record 36 of Set 7 | komatipoort
# Processing Record 37 of Set 7 | nome
# Processing Record 38 of Set 7 | sumbe
# Processing Record 39 of Set 7 | bosaso
# Processing Record 40 of Set 7 | rockhampton
# Processing Record 41 of Set 7 | shangqiu
# Processing Record 42 of Set 7 | chicama
# Processing Record 43 of Set 7 | santa isabel
# Processing Record 44 of Set 7 | navahrudak
# Processing Record 45 of Set 7 | ixtapa
# Processing Record 46 of Set 7 | severnyy-kospashskiy
# Processing Record 47 of Set 7 | verkhnyaya inta
# Processing Record 48 of Set 7 | lasa
# Processing Record 49 of Set 7 | garden city
# Processing Record 50 of Set 7 | san cristobal
# Processing Record 1 of Set 8 | alexandria
# Processing Record 2 of Set 8 | buchanan
# Processing Record 3 of Set 8 | onega
# Processing Record 4 of Set 8 | peleduy
# Processing Record 5 of Set 8 | gazojak
# Processing Record 6 of Set 8 | nantucket
# Processing Record 7 of Set 8 | shenzhen
# Processing Record 8 of Set 8 | aguas vermelhas
# Processing Record 9 of Set 8 | tingrela
# City not found. Skipping...
# Processing Record 10 of Set 8 | denpasar
# Processing Record 11 of Set 8 | crevenicu
# Processing Record 12 of Set 8 | vila franca do campo
# Processing Record 13 of Set 8 | hamilton
# Processing Record 14 of Set 8 | campbeltown
# Processing Record 15 of Set 8 | kidal
# Processing Record 16 of Set 8 | sao goncalo do amarante
# Processing Record 17 of Set 8 | clyde river
# Processing Record 18 of Set 8 | muswellbrook
# Processing Record 19 of Set 8 | ziniare
# Processing Record 20 of Set 8 | chadiza
# Processing Record 21 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 23 of Set 8 | salekhard
# Processing Record 24 of Set 8 | bud
# Processing Record 25 of Set 8 | ranong
# Processing Record 26 of Set 8 | udalguri
# Processing Record 27 of Set 8 | puerto suarez
# Processing Record 28 of Set 8 | belyy yar
# Processing Record 29 of Set 8 | kathu
# Processing Record 30 of Set 8 | pak phanang
# Processing Record 31 of Set 8 | tianpeng
# Processing Record 32 of Set 8 | hornepayne
# Processing Record 33 of Set 8 | matay
# Processing Record 34 of Set 8 | wahiawa
# Processing Record 35 of Set 8 | tekeli
# Processing Record 36 of Set 8 | tual
# Processing Record 37 of Set 8 | finnsnes
# Processing Record 38 of Set 8 | eskil
# Processing Record 39 of Set 8 | cartagena
# Processing Record 40 of Set 8 | lander
# Processing Record 41 of Set 8 | xining
# Processing Record 42 of Set 8 | brae
# Processing Record 43 of Set 8 | katsuura
# Processing Record 44 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 45 of Set 8 | matara
# Processing Record 46 of Set 8 | oum hadjer
# Processing Record 47 of Set 8 | karratha
# Processing Record 48 of Set 8 | katiola
# Processing Record 49 of Set 8 | kopavogur
# Processing Record 50 of Set 8 | keflavik
# Processing Record 1 of Set 9 | mulege
# Processing Record 2 of Set 9 | chapais
# Processing Record 3 of Set 9 | rawson
# Processing Record 4 of Set 9 | maragogi
# Processing Record 5 of Set 9 | eyl
# Processing Record 6 of Set 9 | sao filipe
# Processing Record 7 of Set 9 | zonguldak
# Processing Record 8 of Set 9 | kalmunai
# Processing Record 9 of Set 9 | kingaroy
# Processing Record 10 of Set 9 | ancud
# Processing Record 11 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 9 | carnot
# Processing Record 13 of Set 9 | aksay
# Processing Record 14 of Set 9 | prince rupert
# Processing Record 15 of Set 9 | tautira
# Processing Record 16 of Set 9 | yoichi
# Processing Record 17 of Set 9 | komsomolskiy
# Processing Record 18 of Set 9 | klaksvik
# Processing Record 19 of Set 9 | sabang
# Processing Record 20 of Set 9 | methoni
# Processing Record 21 of Set 9 | coos bay
# Processing Record 22 of Set 9 | leningradskiy
# Processing Record 23 of Set 9 | port augusta
# Processing Record 24 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 25 of Set 9 | boa vista
# Processing Record 26 of Set 9 | surt
# Processing Record 27 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 28 of Set 9 | elko
# Processing Record 29 of Set 9 | naron
# Processing Record 30 of Set 9 | zhangye
# Processing Record 31 of Set 9 | pihuamo
# Processing Record 32 of Set 9 | el alto
# Processing Record 33 of Set 9 | misratah
# Processing Record 34 of Set 9 | kasongo-lunda
# Processing Record 35 of Set 9 | saint-georges
# Processing Record 36 of Set 9 | fiumicino
# Processing Record 37 of Set 9 | mahebourg
# Processing Record 38 of Set 9 | san jose
# Processing Record 39 of Set 9 | vredendal
# Processing Record 40 of Set 9 | hualmay
# Processing Record 41 of Set 9 | moindou
# Processing Record 42 of Set 9 | la ronge
# Processing Record 43 of Set 9 | taywarah
# Processing Record 44 of Set 9 | manzil salim
# Processing Record 45 of Set 9 | kudahuvadhoo
# Processing Record 46 of Set 9 | dongsheng
# Processing Record 47 of Set 9 | bataraza
# City not found. Skipping...
# Processing Record 48 of Set 9 | prado
# Processing Record 49 of Set 9 | loviisa
# Processing Record 50 of Set 9 | calvia
# Processing Record 1 of Set 10 | nalut
# Processing Record 2 of Set 10 | mabaruma
# Processing Record 3 of Set 10 | corinth
# Processing Record 4 of Set 10 | khomeyn
# Processing Record 5 of Set 10 | akyab
# Processing Record 6 of Set 10 | takoradi
# Processing Record 7 of Set 10 | apatou
# Processing Record 8 of Set 10 | portobelo
# Processing Record 9 of Set 10 | sergeyevka
# Processing Record 10 of Set 10 | naze
# Processing Record 11 of Set 10 | junagarh
# Processing Record 12 of Set 10 | bati
# Processing Record 13 of Set 10 | ziyang
# Processing Record 14 of Set 10 | lompoc
# Processing Record 15 of Set 10 | carcassonne
# Processing Record 16 of Set 10 | valverde del camino
# Processing Record 17 of Set 10 | vikhorevka
# Processing Record 18 of Set 10 | nagato
# Processing Record 19 of Set 10 | port arthur
# Processing Record 20 of Set 10 | portland
# Processing Record 21 of Set 10 | ogaminana
# Processing Record 22 of Set 10 | dedovichi
# Processing Record 23 of Set 10 | cheuskiny
# City not found. Skipping...
# Processing Record 24 of Set 10 | aripuana
# Processing Record 25 of Set 10 | surazh
# Processing Record 26 of Set 10 | clarence town
# Processing Record 27 of Set 10 | brattvag
# Processing Record 28 of Set 10 | ahuimanu
# Processing Record 29 of Set 10 | khorixas
# Processing Record 30 of Set 10 | svetlaya
# Processing Record 31 of Set 10 | upata
# Processing Record 32 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 10 | asuncion nochixtlan
# Processing Record 34 of Set 10 | itoman
# Processing Record 35 of Set 10 | palauig
# Processing Record 36 of Set 10 | bay city
# Processing Record 37 of Set 10 | cabo san lucas
# Processing Record 38 of Set 10 | mayumba
# Processing Record 39 of Set 10 | zvishavane
# Processing Record 40 of Set 10 | kirkwall
# Processing Record 41 of Set 10 | waitati
# Processing Record 42 of Set 10 | preobrazheniye
# Processing Record 43 of Set 10 | deputatskiy
# Processing Record 44 of Set 10 | nelson bay
# Processing Record 45 of Set 10 | vanimo
# Processing Record 46 of Set 10 | atasu
# Processing Record 47 of Set 10 | bull savanna
# Processing Record 48 of Set 10 | vytegra
# Processing Record 49 of Set 10 | khingansk
# Processing Record 50 of Set 10 | bedesa
# Processing Record 1 of Set 11 | hoi an
# Processing Record 2 of Set 11 | linkoping
# Processing Record 3 of Set 11 | mayor pablo lagerenza
# Processing Record 4 of Set 11 | caravelas
# Processing Record 5 of Set 11 | abnub
# Processing Record 6 of Set 11 | lagoa da prata
# Processing Record 7 of Set 11 | harwich
# Processing Record 8 of Set 11 | pinillos
# Processing Record 9 of Set 11 | monte patria
# Processing Record 10 of Set 11 | dawei
# Processing Record 11 of Set 11 | nyurba
# Processing Record 12 of Set 11 | itarema
# Processing Record 13 of Set 11 | tyup
# Processing Record 14 of Set 11 | cullman
# Processing Record 15 of Set 11 | paamiut
# Processing Record 16 of Set 11 | palmer
# Processing Record 17 of Set 11 | sherpur
# Processing Record 18 of Set 11 | juneau
# Processing Record 19 of Set 11 | sayyan
# Processing Record 20 of Set 11 | kloulklubed
# Processing Record 21 of Set 11 | kurumkan
# Processing Record 22 of Set 11 | hrebinka
# Processing Record 23 of Set 11 | vao
# Processing Record 24 of Set 11 | mindelheim
# Processing Record 25 of Set 11 | cervo
# Processing Record 26 of Set 11 | lata
# Processing Record 27 of Set 11 | mazatlan
# Processing Record 28 of Set 11 | port-gentil
# Processing Record 29 of Set 11 | kirkland lake
# Processing Record 30 of Set 11 | bathsheba
# Processing Record 31 of Set 11 | dalby
# Processing Record 32 of Set 11 | campbell river
# Processing Record 33 of Set 11 | lidkoping
# Processing Record 34 of Set 11 | broome
# Processing Record 35 of Set 11 | birin
# Processing Record 36 of Set 11 | huanren
# Processing Record 37 of Set 11 | maroantsetra
# Processing Record 38 of Set 11 | ararat
# Processing Record 39 of Set 11 | cehegin
# Processing Record 40 of Set 11 | egvekinot
# Processing Record 41 of Set 11 | haapu
# City not found. Skipping...
# Processing Record 42 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 43 of Set 11 | ishigaki
# Processing Record 44 of Set 11 | castro alves
# Processing Record 45 of Set 11 | saint anthony
# Processing Record 46 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 11 | lima
# Processing Record 48 of Set 11 | grand-santi
# Processing Record 49 of Set 11 | ginir
# Processing Record 50 of Set 11 | olafsvik
# Processing Record 1 of Set 12 | tigil
# Processing Record 2 of Set 12 | berbera
# Processing Record 3 of Set 12 | kununurra
# Processing Record 4 of Set 12 | abilene
# Processing Record 5 of Set 12 | soyo
# Processing Record 6 of Set 12 | sao raimundo nonato
# Processing Record 7 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 8 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 9 of Set 12 | loukhi
# Processing Record 10 of Set 12 | irbit
# Processing Record 11 of Set 12 | sur
# Processing Record 12 of Set 12 | biggar
# Processing Record 13 of Set 12 | pontian kecil
# Processing Record 14 of Set 12 | bama
# Processing Record 15 of Set 12 | gurgan
# City not found. Skipping...
# Processing Record 16 of Set 12 | porto novo
# Processing Record 17 of Set 12 | acapulco
# Processing Record 18 of Set 12 | morondava
# Processing Record 19 of Set 12 | baturaja
# Processing Record 20 of Set 12 | abidjan
# Processing Record 21 of Set 12 | georgiyevka
# Processing Record 22 of Set 12 | raudeberg
# Processing Record 23 of Set 12 | saint-joseph
# Processing Record 24 of Set 12 | mingaora
# Processing Record 25 of Set 12 | geraldton
# Processing Record 26 of Set 12 | codigoro
# Processing Record 27 of Set 12 | sisimiut
# Processing Record 28 of Set 12 | vostok
# Processing Record 29 of Set 12 | santiago del estero
# Processing Record 30 of Set 12 | nagorsk
# Processing Record 31 of Set 12 | bongandanga
# Processing Record 32 of Set 12 | taltal
# Processing Record 33 of Set 12 | horsham
# Processing Record 34 of Set 12 | alofi
# Processing Record 35 of Set 12 | comodoro rivadavia
# Processing Record 36 of Set 12 | arlit
# Processing Record 37 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 38 of Set 12 | kaeo
# Processing Record 39 of Set 12 | trebinje
# Processing Record 40 of Set 12 | lakselv
# Processing Record 41 of Set 12 | ardistan
# City not found. Skipping...
# Processing Record 42 of Set 12 | motygino
# Processing Record 43 of Set 12 | wakema
# Processing Record 44 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 45 of Set 12 | jertih
# Processing Record 46 of Set 12 | suntar
# Processing Record 47 of Set 12 | afmadu
# City not found. Skipping...
# Processing Record 48 of Set 12 | fairbanks
# Processing Record 49 of Set 12 | manadhoo
# Processing Record 50 of Set 12 | vila do maio
# Processing Record 1 of Set 13 | henties bay
# Processing Record 2 of Set 13 | atambua
# Processing Record 3 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 13 | valer
# Processing Record 5 of Set 13 | ystad
# Processing Record 6 of Set 13 | nara
# Processing Record 7 of Set 13 | livadiya
# Processing Record 8 of Set 13 | darhan
# Processing Record 9 of Set 13 | novobirilyussy
# Processing Record 10 of Set 13 | chara
# Processing Record 11 of Set 13 | alice springs
# Processing Record 12 of Set 13 | tectitan
# City not found. Skipping...
# Processing Record 13 of Set 13 | tongliao
# Processing Record 14 of Set 13 | palana
# Processing Record 15 of Set 13 | benjamin constant
# Processing Record 16 of Set 13 | baringo
# Processing Record 17 of Set 13 | muros
# Processing Record 18 of Set 13 | karakulino
# Processing Record 19 of Set 13 | marinette
# Processing Record 20 of Set 13 | emerald
# Processing Record 21 of Set 13 | yako
# Processing Record 22 of Set 13 | maldonado
# Processing Record 23 of Set 13 | walvis bay
# Processing Record 24 of Set 13 | murillo
# Processing Record 25 of Set 13 | yingshang
# City not found. Skipping...
# Processing Record 26 of Set 13 | bantry
# Processing Record 27 of Set 13 | gold coast
# Processing Record 28 of Set 13 | zemetchino
# Processing Record 29 of Set 13 | dalnerechensk
# Processing Record 30 of Set 13 | cabra
# Processing Record 31 of Set 13 | kiunga
# Processing Record 32 of Set 13 | tahoua
# Processing Record 33 of Set 13 | sakaraha
# Processing Record 34 of Set 13 | itaituba
# Processing Record 35 of Set 13 | batagay-alyta
# Processing Record 36 of Set 13 | erenhot
# Processing Record 37 of Set 13 | atar
# Processing Record 38 of Set 13 | port macquarie
# Processing Record 39 of Set 13 | payo
# Processing Record 40 of Set 13 | valdivia
# Processing Record 41 of Set 13 | aporawan
# City not found. Skipping...
# Processing Record 42 of Set 13 | pietarsaari
# Processing Record 43 of Set 13 | carauari
# Processing Record 44 of Set 13 | kiel
# Processing Record 45 of Set 13 | ribeira grande
# Processing Record 46 of Set 13 | katangli
# Processing Record 47 of Set 13 | mujiayingzi
# Processing Record 48 of Set 13 | poshekhonye
# Processing Record 49 of Set 13 | gamba
# Processing Record 50 of Set 13 | aklavik
# Processing Record 1 of Set 14 | dzaoudzi
# Processing Record 2 of Set 14 | hasaki
# Processing Record 3 of Set 14 | elmina
# Processing Record 4 of Set 14 | labuhan
# Processing Record 5 of Set 14 | roquebrune-cap-martin
# Processing Record 6 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 14 | bacabal
# Processing Record 8 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 9 of Set 14 | dapaong
# Processing Record 10 of Set 14 | gornoye loo
# Processing Record 11 of Set 14 | saldanha
# Processing Record 12 of Set 14 | xianyang
# Processing Record 13 of Set 14 | fredericksburg
# Processing Record 14 of Set 14 | vila velha
# Processing Record 15 of Set 14 | koboldo
# City not found. Skipping...
# Processing Record 16 of Set 14 | san luis
# Processing Record 17 of Set 14 | milledgeville
# Processing Record 18 of Set 14 | merauke
# Processing Record 19 of Set 14 | victor harbor
# Processing Record 20 of Set 14 | shadegan
# Processing Record 21 of Set 14 | bulgan
# Processing Record 22 of Set 14 | krasnoarmeysk
# Processing Record 23 of Set 14 | rassvet
# Processing Record 24 of Set 14 | kolokani
# Processing Record 25 of Set 14 | narsipatnam
# Processing Record 26 of Set 14 | gat
# Processing Record 27 of Set 14 | cassilandia
# Processing Record 28 of Set 14 | kvareli
# Processing Record 29 of Set 14 | fare
# Processing Record 30 of Set 14 | silifke
# Processing Record 31 of Set 14 | reconquista
# Processing Record 32 of Set 14 | pochutla
# Processing Record 33 of Set 14 | bilma
# Processing Record 34 of Set 14 | dutse
# Processing Record 35 of Set 14 | hit
# Processing Record 36 of Set 14 | larap
# Processing Record 37 of Set 14 | shimanovsk
# Processing Record 38 of Set 14 | skagen
# Processing Record 39 of Set 14 | salinopolis
# Processing Record 40 of Set 14 | nivala
# Processing Record 41 of Set 14 | cay
# Processing Record 42 of Set 14 | russell
# Processing Record 43 of Set 14 | camana
# Processing Record 44 of Set 14 | beisfjord
# Processing Record 45 of Set 14 | dhidhdhoo
# Processing Record 46 of Set 14 | mondlo
# Processing Record 47 of Set 14 | waddan
# Processing Record 48 of Set 14 | aberlady
# City not found. Skipping...
# Processing Record 49 of Set 14 | sedelnikovo
# City not found. Skipping...
# Processing Record 50 of Set 14 | uttaradit
# Processing Record 1 of Set 15 | tabarqah
# City not found. Skipping...
# Processing Record 2 of Set 15 | liniere
# City not found. Skipping...
# Processing Record 3 of Set 15 | miraflores
# Processing Record 4 of Set 15 | jibuti
# Processing Record 5 of Set 15 | sambava
# Processing Record 6 of Set 15 | san patricio
# Processing Record 7 of Set 15 | mayo
# Processing Record 8 of Set 15 | consuelo
# Processing Record 9 of Set 15 | touros
# Processing Record 10 of Set 15 | port hedland
# Processing Record 11 of Set 15 | wasilla
# Processing Record 12 of Set 15 | ballyshannon
# Processing Record 13 of Set 15 | hibbing
# Processing Record 14 of Set 15 | road town
# Processing Record 15 of Set 15 | krasnoyarsk-66
# City not found. Skipping...
# Processing Record 16 of Set 15 | ugoofaaru
# Processing Record 17 of Set 15 | tillabery
# City not found. Skipping...
# Processing Record 18 of Set 15 | korla
# Processing Record 19 of Set 15 | viedma
# Processing Record 20 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 21 of Set 15 | trujillo
# Processing Record 22 of Set 15 | alyangula
# Processing Record 23 of Set 15 | mocuba
# Processing Record 24 of Set 15 | beidao
# Processing Record 25 of Set 15 | mrirt
# City not found. Skipping...
# Processing Record 26 of Set 15 | mbini
# Processing Record 27 of Set 15 | makat
# Processing Record 28 of Set 15 | cuamba
# Processing Record 29 of Set 15 | nizhnevartovsk
# Processing Record 30 of Set 15 | termini imerese
# Processing Record 31 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 32 of Set 15 | sofiysk
# City not found. Skipping...
# Processing Record 33 of Set 15 | zakamensk
# Processing Record 34 of Set 15 | el balyana
# City not found. Skipping...
# Processing Record 35 of Set 15 | aranos
# Processing Record 36 of Set 15 | fuyu
# Processing Record 37 of Set 15 | batagay
# Processing Record 38 of Set 15 | benguela
# Processing Record 39 of Set 15 | namatanai
# Processing Record 40 of Set 15 | filingue
# Processing Record 41 of Set 15 | ascension
# Processing Record 42 of Set 15 | shubarshi
# Processing Record 43 of Set 15 | inuvik
# Processing Record 44 of Set 15 | san francisco
# Processing Record 45 of Set 15 | wyszkow
# Processing Record 46 of Set 15 | jacareacanga
# Processing Record 47 of Set 15 | nicoya
# Processing Record 48 of Set 15 | ziarat
# Processing Record 49 of Set 15 | keningau
# Processing Record 50 of Set 15 | ushtobe
# Processing Record 1 of Set 16 | mackay
# Processing Record 2 of Set 16 | okha
# Processing Record 3 of Set 16 | tingo maria
# Processing Record 4 of Set 16 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 5 of Set 16 | trelew
# Processing Record 6 of Set 16 | senador jose porfirio
# Processing Record 7 of Set 16 | angoram
# Processing Record 8 of Set 16 | araouane
# Processing Record 9 of Set 16 | aflu
# City not found. Skipping...
# Processing Record 10 of Set 16 | jutiapa
# Processing Record 11 of Set 16 | sangolqui
# Processing Record 12 of Set 16 | lishui
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Hilo  19.7297 -155.0900     88.29        86         100       13.80
# 1     Pitimbu  -7.4706  -34.8086     73.99        81           4       10.36
# 2       Lagoa  39.0500  -27.9833     74.55        85          20        9.75
# 3   Busselton -33.6500  115.3333     54.70        70          83        7.54
# 4  Nikolskoye  59.7035   30.7861     67.91        83          48        5.48
# 5    Cabedelo  -6.9811  -34.8339     74.07        81           6       11.23
# 6     Mataura -46.1927  168.8643     57.47        73          92        4.03
# 7       Vaini -21.2000 -175.2000     75.36       100          75       13.80
# 8  Hambantota   6.1241   81.1185     77.79        80         100       16.24
# 9   Upernavik  72.7868  -56.1549     40.75        93          83       10.89
#
#   Country       Description
# 0      US     moderate rain
# 1      BR         clear sky
# 2      PT        few clouds
# 3      AU     broken clouds
# 4      RU  scattered clouds
# 5      BR         clear sky
# 6      NZ   overcast clouds
# 7      TO     broken clouds
# 8      LK   overcast clouds
# 9      GL     broken clouds

# %%
# Rearrange the columns in the DataFrame
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Hilo      US  19.7297 -155.0900     88.29        86         100
# 1     Pitimbu      BR  -7.4706  -34.8086     73.99        81           4
# 2       Lagoa      PT  39.0500  -27.9833     74.55        85          20
# 3   Busselton      AU -33.6500  115.3333     54.70        70          83
# 4  Nikolskoye      RU  59.7035   30.7861     67.91        83          48
#
#    Wind Speed       Description
# 0       13.80     moderate rain
# 1       10.36         clear sky
# 2        9.75        few clouds
# 3        7.54     broken clouds
# 4        5.48  scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
